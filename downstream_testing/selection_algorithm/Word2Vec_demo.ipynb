# %%
# Library Imports

import pandas as pd # provide sql-like data manipulation tools. very handy.
pd.options.mode.chained_assignment = None
import numpy as np # high dimensional vector computing library.
from copy import deepcopy
from string import punctuation
from random import shuffle

import gensim
from gensim.models.word2vec import Word2Vec # the word2vec model gensim class

from tqdm import tqdm
tqdm.pandas(desc="progress-bar")

from nltk.tokenize import TweetTokenizer # a tweet tokenizer from nltk.
tokenizer = TweetTokenizer()
from gensim.models.doc2vec import TaggedDocument



from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.sequence import pad_sequences
import gensim.downloader

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

# %%
main_data = pd.read_csv('/Users/andrewsimon/Desktop/Dow_dat.csv')
main_data
# Out:
#      Level                                             Report
# 0        2  On April 10th at 12:30 PM, there was an incide...
# 1        3  On April 8th at 9:00 PM, a fire broke out in t...
# 2        4  On April 6th at 2:45 AM, there was an incident...
# 3        1  On April 5th at 7:15 PM, there was an unplanne...
# 4        5  On April 2nd at 11:30 AM, there was a minor in...
# ..     ...                                                ...
# 295      3  At 9:45 AM, a worker reported a small leak of ...
# 296      5  At 2:30 PM, a worker reported a small spill of...
# 297      4  At 6:15 AM, a worker reported an unusual odor ...
# 298      2  At 11:00 AM, a worker reported a small fire in...
# 299      1  At 4:00 PM, an unplanned event occurred in the...
#
# [300 rows x 2 columns]

# %%
main_data['title'] = main_data['Report'].apply(lambda x: gensim.utils.simple_preprocess(x))

# %%
# Tokenizer helper function
def tokenize(report):
    try:
        tokens = tokenizer.tokenize(report)
        return tokens
    except:
        return "NC"
    
# Tokenizer wrapping function
def postprocess(data):
    data['tokens'] = data['Report'].progress_map(tokenize)
    data = data[data.tokens != 'NC']
    data.reset_index(inplace=True)
    data.drop('index', inplace=True, axis=1)
    return data

# %%
# Tokenize the data with wrapping functions
data = main_data.copy()
data = postprocess(data)
# Out:
# progress-bar: 100%|██████████| 300/300 [00:00<00:00, 5044.14it/s]

# %%
# Train test split 
X_train, X_test, y_train, y_test = train_test_split(np.array(data.tokens),
                                                    np.array(data.Level), test_size=0.2, random_state=42)

# %%
X_train
# Out:
# array([list(['At', '2:15', 'PM', ',', 'a', 'worker', 'reported', 'a', 'small', 'fire', 'in', 'the', 'storage', 'area', 'for', 'chemical', 'C', '.', 'The', 'fire', 'was', 'caused', 'by', 'a', 'faulty', 'electrical', 'connection', 'in', 'a', 'piece', 'of', 'equipment', '.', 'The', 'fire', 'was', 'quickly', 'extinguished', 'using', 'the', 'appropriate', 'fire', 'suppression', 'materials', ',', 'and', 'the', 'impacted', 'area', 'was', 'inspected', 'for', 'any', 'additional', 'hazards', '.', 'No', 'injuries', 'or', 'environmental', 'impacts', 'were', 'reported', '.']),
#        list(['On', 'October', '22nd', 'at', '1:00', 'AM', ',', 'there', 'was', 'a', 'major', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'incident', 'occurred', 'during', 'the', 'reaction', 'process', 'in', 'the', 'reaction', 'unit', '.', 'A', 'large', 'amount', 'of', 'chemical', 'A', 'was', 'released', 'into', 'the', 'atmosphere', 'due', 'to', 'a', 'catastrophic', 'failure', 'of', 'the', 'reactor', '.', 'The', 'situation', 'was', 'contained', 'by', 'the', "plant's", 'emergency', 'response', 'team', ',', 'but', 'significant', 'damage', 'was', 'done', 'to', 'the', 'plant', 'and', 'the', 'surrounding', 'environment', '.', 'All', 'employees', 'were', 'safely', 'evacuated', ',', 'and', 'there', 'were', 'no', 'injuries', 'reported', '.', 'The', 'plant', 'is', 'currently', 'shut', 'down', 'for', 'repairs', '.']),
#        list(['On', 'March', '25th', 'at', '2:30', 'PM', ',', 'there', 'was', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'incident', 'occurred', 'during', 'the', 'separation', 'process', 'in', 'the', 'separation', 'unit', '.', 'A', 'failure', 'in', 'the', 'separation', 'unit', 'caused', 'a', 'small', 'amount', 'of', 'chemical', 'C', 'to', 'be', 'released', 'into', 'the', 'environment', '.', 'The', 'situation', 'was', 'quickly', 'contained', 'by', 'the', "plant's", 'emergency', 'response', 'team', ',', 'and', 'the', 'malfunctioning', 'equipment', 'was', 'shut', 'down', 'for', 'repairs', '.', 'No', 'injuries', 'were', 'reported', '.']),
#        list(['There', 'has', 'been', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'A', 'small', 'leak', 'was', 'discovered', 'in', 'a', 'pipe', 'in', 'the', 'separation', 'unit', ',', 'resulting', 'in', 'a', 'small', 'release', 'of', 'chemicals', 'A', 'and', 'B', '.', 'The', 'leak', 'was', 'quickly', 'repaired', ',', 'and', 'no', 'injuries', 'were', 'reported', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['There', 'has', 'been', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'During', 'the', 'transfer', 'of', 'chemical', 'B', 'from', 'the', 'storage', 'tank', 'to', 'the', 'reaction', 'unit', ',', 'the', 'transfer', 'hose', 'broke', ',', 'causing', 'a', 'release', 'of', 'the', 'chemical', '.', 'The', 'release', 'was', 'contained', 'within', 'the', "plant's", 'boundaries', ',', 'but', 'some', 'workers', 'in', 'the', 'area', 'were', 'exposed', 'to', 'the', 'chemical', '.', 'The', 'workers', 'were', 'decontaminated', 'and', 'sent', 'for', 'medical', 'evaluation', '.', 'No', 'serious', 'injuries', 'were', 'reported', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['On', 'January', '17th', 'at', '1:00', 'PM', ',', 'there', 'was', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'incident', 'occurred', 'during', 'the', 'separation', 'process', 'in', 'the', 'separation', 'unit', '.', 'A', 'malfunction', 'in', 'the', 'separator', 'caused', 'a', 'small', 'amount', 'of', 'chemical', 'B', 'to', 'be', 'released', 'into', 'the', 'environment', '.', 'The', 'situation', 'was', 'quickly', 'contained', 'by', 'the', "plant's", 'emergency', 'response', 'team', ',', 'and', 'the', 'malfunctioning', 'equipment', 'was', 'shut', 'down', 'for', 'repairs', '.', 'No', 'injuries', 'were', 'reported', '.']),
#        list(['On', 'February', '10th', 'at', '8:', '15', 'PM', ',', 'there', 'was', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'incident', 'occurred', 'during', 'the', 'separation', 'process', 'in', 'the', 'separation', 'unit', '.', 'A', 'failure', 'in', 'the', 'separator', 'caused', 'a', 'small', 'amount', 'of', 'chemicals', 'A', 'and', 'B', 'to', 'be', 'released', 'into', 'the', 'environment', '.', 'The', 'situation', 'was', 'quickly', 'contained', 'by', 'the', "plant's", 'emergency', 'response', 'team', ',', 'and', 'the', 'malfunctioning', 'equipment', 'was', 'shut', 'down', 'for', 'repairs', '.', 'No', 'injuries', 'were', 'reported', '.']),
#        list(['At', '8:', '15', 'AM', ',', 'a', 'worker', 'reported', 'a', 'leak', 'in', 'one', 'of', 'the', 'storage', 'tanks', 'for', 'chemical', 'B', '.', 'The', 'leak', 'was', 'caused', 'by', 'a', 'crack', 'in', 'the', 'tank', ',', 'and', 'the', 'affected', 'area', 'was', 'quickly', 'cordoned', 'off', 'to', 'prevent', 'any', 'further', 'leaks', '.', 'The', 'leak', 'was', 'contained', 'using', 'the', 'appropriate', 'spill', 'containment', 'materials', ',', 'and', 'the', 'damaged', 'tank', 'was', 'replaced', '.', 'No', 'injuries', 'were', 'reported', ',', 'but', 'the', 'environmental', 'impact', 'of', 'the', 'incident', 'is', 'currently', 'being', 'assessed', '.']),
#        list(['On', 'October', '31st', 'at', '6:00', 'PM', ',', 'there', 'was', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'incident', 'occurred', 'during', 'the', 'reaction', 'process', 'in', 'the', 'reaction', 'unit', '.', 'A', 'valve', 'failure', 'caused', 'a', 'leak', 'in', 'the', 'transfer', 'line', ',', 'and', 'a', 'small', 'amount', 'of', 'chemical', 'B', 'was', 'released', 'into', 'the', 'environment', '.', 'The', 'situation', 'was', 'quickly', 'contained', 'by', 'the', "plant's", 'emergency', 'response', 'team', ',', 'and', 'the', 'affected', 'line', 'was', 'taken', 'offline', 'for', 'repairs', '.', 'No', 'injuries', 'were', 'reported', '.']),
#        list(['There', 'has', 'been', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'A', 'malfunction', 'in', 'the', 'reaction', 'unit', 'caused', 'a', 'small', 'release', 'of', 'chemicals', 'A', 'and', 'B', 'into', 'the', 'environment', '.', 'The', 'release', 'was', 'contained', 'within', 'the', "plant's", 'boundaries', ',', 'and', 'no', 'injuries', 'were', 'reported', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['There', 'has', 'been', 'a', 'minor', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'One', 'of', 'the', 'pumps', 'in', 'the', 'storage', 'area', 'malfunctioned', ',', 'causing', 'a', 'small', 'spill', 'of', 'chemical', 'C', 'onto', 'the', 'floor', '.', 'The', 'spill', 'was', 'immediately', 'reported', ',', 'and', 'the', 'spill', 'response', 'team', 'was', 'activated', '.', 'The', 'spill', 'was', 'contained', 'within', 'the', 'designated', 'area', 'and', 'cleaned', 'up', 'using', 'absorbent', 'material', '.', 'The', 'area', 'was', 'then', 'decontaminated', '.', 'No', 'injuries', 'were', 'reported', ',', 'and', 'the', 'spill', 'did', 'not', 'affect', 'production', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['There', 'has', 'been', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'One', 'of', 'the', 'pipes', 'in', 'the', 'separation', 'unit', 'was', 'not', 'properly', 'maintained', 'and', 'failed', ',', 'causing', 'a', 'release', 'of', 'chemical', 'C', '.', 'The', 'release', 'was', 'quickly', 'contained', 'within', 'the', 'designated', 'area', ',', 'and', 'the', 'chemical', 'was', 'recovered', '.', 'No', 'injuries', 'were', 'reported', ',', 'and', 'the', 'incident', 'did', 'not', 'affect', 'production', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['At', '11:00', 'PM', ',', 'an', 'explosion', 'occurred', 'in', 'the', 'reaction', 'unit', ',', 'resulting', 'in', 'a', 'fire', '.', 'The', 'cause', 'of', 'the', 'explosion', 'is', 'currently', 'unknown', 'and', 'is', 'under', 'investigation', '.', 'The', 'fire', 'was', 'quickly', 'extinguished', 'using', 'the', 'appropriate', 'fire', 'suppression', 'materials', ',', 'and', 'the', 'impacted', 'area', 'was', 'inspected', 'for', 'any', 'additional', 'hazards', '.', 'Three', 'workers', 'were', 'injured', 'and', 'taken', 'to', 'the', 'hospital', 'for', 'treatment', '.']),
#        list(['There', 'has', 'been', 'a', 'serious', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'A', 'large', 'release', 'of', 'chemical', 'B', 'occurred', 'in', 'the', 'separation', 'unit', ',', 'causing', 'a', 'fire', 'and', 'significant', 'damage', 'to', 'the', 'plant', '.', 'The', 'emergency', 'response', 'team', 'quickly', 'responded', 'to', 'the', 'incident', ',', 'and', 'the', 'fire', 'was', 'extinguished', '.', 'Unfortunately', ',', 'three', 'workers', 'were', 'injured', 'in', 'the', 'incident', 'and', 'have', 'been', 'transported', 'to', 'the', 'hospital', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'a', 'thorough', 'investigation', 'will', 'be', 'conducted', 'to', 'determine', 'the', 'cause', 'of', 'the', 'release', '.']),
#        list(['There', 'has', 'been', 'an', 'unplanned', 'event', 'at', 'the', 'chemical', 'plant', '.', 'One', 'of', 'the', 'vessels', 'in', 'the', 'reaction', 'unit', 'ruptured', ',', 'causing', 'a', 'release', 'of', 'chemicals', 'A', 'and', 'B', '.', 'The', 'release', 'led', 'to', 'a', 'chain', 'reaction', 'resulting', 'in', 'a', 'large', 'fire', 'that', 'caused', 'significant', 'damage', 'to', 'the', "plant's", 'infrastructure', 'and', 'equipment', '.', 'The', 'fire', 'was', 'eventually', 'extinguished', ',', 'but', 'several', 'employees', 'were', 'injured', '.', 'The', 'injured', 'employees', 'were', 'transported', 'to', 'the', 'hospital', ',', 'and', 'the', 'plant', 'was', 'evacuated', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['At', '4:45', 'PM', ',', 'a', 'worker', 'reported', 'a', 'malfunctioning', 'pump', 'in', 'the', 'reaction', 'unit', '.', 'The', 'affected', 'area', 'was', 'quickly', 'cordoned', 'off', 'to', 'prevent', 'any', 'further', 'issues', '.', 'The', 'issue', 'was', 'resolved', 'by', 'replacing', 'the', 'faulty', 'pump', '.', 'No', 'injuries', 'or', 'environmental', 'impacts', 'were', 'reported', '.']),
#        list(['On', 'August', '14th', 'at', '9:00', 'PM', ',', 'there', 'was', 'a', 'minor', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'incident', 'occurred', 'during', 'the', 'transfer', 'of', 'chemical', 'C', 'from', 'the', 'separation', 'unit', 'to', 'the', 'storage', 'area', '.', 'A', 'small', 'spill', 'was', 'detected', 'on', 'the', 'transfer', 'line', ',', 'and', 'the', 'situation', 'was', 'quickly', 'contained', 'by', 'the', "plant's", 'emergency', 'response', 'team', '.', 'The', 'affected', 'line', 'was', 'taken', 'offline', 'for', 'repairs', ',', 'and', 'the', 'spilled', 'chemical', 'C', 'was', 'safely', 'disposed', 'of', '.', 'No', 'injuries', 'were', 'reported', '.']),
#        list(['On', 'August', '8th', 'at', '6:30', 'AM', ',', 'there', 'was', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'incident', 'occurred', 'during', 'the', 'transfer', 'of', 'chemical', 'B', 'from', 'the', 'storage', 'area', 'to', 'the', 'reaction', 'unit', '.', 'A', 'small', 'leak', 'was', 'detected', 'on', 'the', 'transfer', 'line', ',', 'and', 'the', 'situation', 'was', 'quickly', 'contained', 'by', 'the', "plant's", 'emergency', 'response', 'team', '.', 'The', 'affected', 'line', 'was', 'taken', 'offline', 'for', 'repairs', ',', 'and', 'the', 'leaked', 'chemical', 'B', 'was', 'safely', 'disposed', 'of', '.', 'No', 'injuries', 'were', 'reported', '.']),
#        list(['On', 'October', '1st', 'at', '6:00', 'PM', ',', 'there', 'was', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'incident', 'occurred', 'during', 'the', 'reaction', 'process', 'in', 'the', 'reaction', 'unit', '.', 'A', 'small', 'fire', 'was', 'detected', 'due', 'to', 'an', 'overheating', 'issue', ',', 'which', 'caused', 'a', 'chemical', 'reaction', 'to', 'occur', '.', 'The', 'situation', 'was', 'quickly', 'contained', 'by', 'the', "plant's", 'emergency', 'response', 'team', ',', 'and', 'the', 'affected', 'equipment', 'was', 'shut', 'down', 'for', 'repairs', '.', 'No', 'injuries', 'were', 'reported', '.']),
#        list(['At', '3:45', 'PM', ',', 'a', 'worker', 'reported', 'a', 'small', 'fire', 'in', 'the', 'storage', 'area', '.', 'The', 'fire', 'was', 'quickly', 'extinguished', 'using', 'the', 'appropriate', 'fire', 'suppression', 'materials', '.', 'The', 'cause', 'of', 'the', 'fire', 'was', 'determined', 'to', 'be', 'a', 'spark', 'from', 'a', 'piece', 'of', 'equipment', '.', 'The', 'affected', 'area', 'was', 'cordoned', 'off', ',', 'and', 'the', 'equipment', 'was', 'repaired', '.', 'No', 'injuries', 'or', 'environmental', 'impacts', 'were', 'reported', '.']),
#        list(['There', 'has', 'been', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'level', 'of', 'chemical', 'B', 'in', 'the', 'storage', 'tank', 'dropped', 'below', 'the', 'minimum', 'required', 'level', ',', 'causing', 'a', 'temporary', 'loss', 'of', 'control', 'in', 'the', 'process', '.', 'The', 'situation', 'was', 'quickly', 'resolved', ',', 'and', 'the', 'process', 'was', 'brought', 'back', 'under', 'control', '.', 'No', 'chemicals', 'were', 'released', ',', 'and', 'no', 'injuries', 'were', 'reported', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['There', 'has', 'been', 'an', 'unplanned', 'event', 'at', 'the', 'chemical', 'plant', '.', 'A', 'truck', 'delivering', 'chemical', 'B', 'to', 'the', 'plant', 'was', 'involved', 'in', 'an', 'accident', 'on', 'the', 'nearby', 'highway', '.', 'The', 'truck', 'was', 'carrying', 'a', 'large', 'quantity', 'of', 'chemical', 'B', ',', 'and', 'a', 'significant', 'amount', 'was', 'spilled', 'on', 'the', 'highway', '.', 'Emergency', 'services', 'were', 'called', 'to', 'the', 'scene', ',', 'and', 'the', 'highway', 'was', 'closed', 'for', 'several', 'hours', '.', 'No', 'injuries', 'were', 'reported', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['On', 'February', '19th', 'at', '1:30', 'PM', ',', 'there', 'was', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'incident', 'occurred', 'during', 'the', 'reaction', 'process', 'in', 'the', 'reaction', 'unit', '.', 'A', 'malfunction', 'in', 'the', 'reactor', 'caused', 'a', 'small', 'amount', 'of', 'chemical', 'A', 'to', 'be', 'released', 'into', 'the', 'atmosphere', '.', 'The', 'situation', 'was', 'quickly', 'contained', 'by', 'the', "plant's", 'emergency', 'response', 'team', ',', 'and', 'the', 'reactor', 'was', 'shut', 'down', 'for', 'repairs', '.', 'No', 'injuries', 'were', 'reported', '.']),
#        list(['There', 'has', 'been', 'an', 'unplanned', 'event', 'at', 'the', 'chemical', 'plant', '.', 'One', 'of', 'the', 'vessels', 'in', 'the', 'reaction', 'unit', 'ruptured', ',', 'causing', 'a', 'release', 'of', 'chemicals', 'A', 'and', 'B', '.', 'This', 'led', 'to', 'a', 'chain', 'reaction', 'resulting', 'in', 'a', 'large', 'explosion', '.', 'The', 'explosion', 'caused', 'significant', 'damage', 'to', 'the', "plant's", 'infrastructure', 'and', 'equipment', ',', 'and', 'several', 'employees', 'were', 'injured', '.', 'The', 'injured', 'employees', 'were', 'transported', 'to', 'the', 'hospital', ',', 'and', 'the', 'plant', 'was', 'evacuated', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['On', 'August', '23rd', 'at', '2:00', 'PM', ',', 'there', 'was', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'incident', 'occurred', 'during', 'the', 'transfer', 'of', 'chemical', 'A', 'from', 'the', 'storage', 'area', 'to', 'the', 'reaction', 'unit', '.', 'A', 'small', 'leak', 'was', 'detected', 'on', 'the', 'transfer', 'line', ',', 'and', 'the', 'situation', 'was', 'quickly', 'contained', 'by', 'the', "plant's", 'emergency', 'response', 'team', '.', 'The', 'affected', 'line', 'was', 'taken', 'offline', 'for', 'repairs', ',', 'and', 'the', 'leaked', 'chemical', 'A', 'was', 'safely', 'disposed', 'of', '.', 'No', 'injuries', 'were', 'reported', '.']),
#        list(['There', 'has', 'been', 'an', 'unplanned', 'event', 'at', 'the', 'chemical', 'plant', '.', 'Chemical', 'A', 'was', 'improperly', 'handled', 'and', 'caused', 'a', 'major', 'release', 'of', 'gas', ',', 'leading', 'to', 'an', 'explosion', '.', 'The', 'explosion', 'damaged', 'the', 'reaction', 'and', 'separation', 'units', 'and', 'caused', 'a', 'fire', '.', 'The', "plant's", 'emergency', 'response', 'team', 'immediately', 'activated', 'and', 'contained', 'the', 'fire', '.', 'The', 'injured', 'employees', 'were', 'transported', 'to', 'the', 'hospital', ',', 'and', 'the', 'plant', 'was', 'evacuated', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['There', 'has', 'been', 'a', 'minor', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'One', 'of', 'the', 'storage', 'tanks', 'for', 'chemical', 'C', 'was', 'overfilled', ',', 'causing', 'a', 'spill', 'onto', 'the', 'floor', '.', 'The', 'spill', 'was', 'immediately', 'reported', ',', 'and', 'the', 'spill', 'response', 'team', 'was', 'activated', '.', 'The', 'spill', 'was', 'contained', 'within', 'the', 'designated', 'area', 'and', 'cleaned', 'up', 'using', 'absorbent', 'material', '.', 'The', 'area', 'was', 'then', 'decontaminated', '.', 'No', 'injuries', 'were', 'reported', ',', 'and', 'the', 'spill', 'did', 'not', 'affect', 'production', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['On', 'September', '13th', 'at', '7:00', 'AM', ',', 'there', 'was', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'incident', 'occurred', 'during', 'the', 'transfer', 'of', 'chemical', 'B', 'from', 'the', 'storage', 'area', 'to', 'the', 'reaction', 'unit', '.', 'A', 'small', 'leak', 'was', 'detected', 'on', 'the', 'transfer', 'line', ',', 'and', 'the', 'situation', 'was', 'quickly', 'contained', 'by', 'the', "plant's", 'emergency', 'response', 'team', '.', 'The', 'affected', 'line', 'was', 'taken', 'offline', 'for', 'repairs', ',', 'and', 'the', 'leaked', 'chemical', 'B', 'was', 'safely', 'disposed', 'of', '.', 'No', 'injuries', 'were', 'reported', '.']),
#        list(['On', 'March', '3rd', 'at', '10:00', 'AM', ',', 'there', 'was', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'incident', 'occurred', 'during', 'the', 'reaction', 'process', 'in', 'the', 'reaction', 'unit', '.', 'A', 'malfunction', 'in', 'the', 'reactor', 'caused', 'a', 'small', 'amount', 'of', 'chemical', 'A', 'to', 'be', 'released', 'into', 'the', 'atmosphere', '.', 'The', 'situation', 'was', 'quickly', 'contained', 'by', 'the', "plant's", 'emergency', 'response', 'team', ',', 'and', 'the', 'reactor', 'was', 'shut', 'down', 'for', 'repairs', '.', 'No', 'injuries', 'were', 'reported', '.']),
#        list(['On', 'March', '16th', 'at', '9:15', 'AM', ',', 'there', 'was', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'incident', 'occurred', 'during', 'the', 'separation', 'process', 'in', 'the', 'separation', 'unit', '.', 'A', 'malfunction', 'in', 'the', 'separator', 'caused', 'a', 'small', 'amount', 'of', 'chemicals', 'A', 'and', 'B', 'to', 'be', 'released', 'into', 'the', 'environment', '.', 'The', 'situation', 'was', 'quickly', 'contained', 'by', 'the', "plant's", 'emergency', 'response', 'team', ',', 'and', 'the', 'malfunctioning', 'equipment', 'was', 'shut', 'down', 'for', 'repairs', '.', 'No', 'injuries', 'were', 'reported', '.']),
#        list(['There', 'has', 'been', 'a', 'non-serious', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'A', 'worker', 'accidentally', 'spilled', 'a', 'small', 'amount', 'of', 'water', 'in', 'the', 'storage', 'area', 'for', 'chemical', 'B', '.', 'The', 'spill', 'was', 'quickly', 'cleaned', 'up', ',', 'and', 'no', 'injuries', 'were', 'reported', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['At', 'approximately', '8:', '00', 'PM', ',', 'there', 'was', 'a', 'power', 'outage', 'in', 'the', 'chemical', 'plant', '.', 'The', 'backup', 'generator', 'was', 'activated', ',', 'but', 'there', 'was', 'a', 'delay', 'in', 'the', 'switch', 'over', '.', 'As', 'a', 'result', ',', 'the', 'reaction', 'unit', 'lost', 'power', ',', 'causing', 'the', 'reaction', 'between', 'chemicals', 'A', 'and', 'B', 'to', 'become', 'unstable', '.', 'The', 'reaction', 'produced', 'excessive', 'heat', ',', 'causing', 'a', 'small', 'fire', '.', 'The', "plant's", 'fire', 'suppression', 'system', 'activated', 'and', 'extinguished', 'the', 'fire', '.', 'No', 'injuries', 'were', 'reported', ',', 'and', 'the', 'reaction', 'unit', 'was', 'shut', 'down', 'for', 'inspection', 'and', 'repairs', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['On', 'September', '25th', 'at', '12:15', 'PM', ',', 'there', 'was', 'a', 'minor', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'incident', 'occurred', 'during', 'the', 'transfer', 'of', 'chemical', 'C', 'from', 'the', 'separation', 'unit', 'to', 'the', 'storage', 'area', '.', 'A', 'small', 'spill', 'was', 'detected', 'on', 'the', 'transfer', 'line', ',', 'and', 'the', 'situation', 'was', 'quickly', 'contained', 'by', 'the', "plant's", 'emergency', 'response', 'team', '.', 'The', 'affected', 'line', 'was', 'taken', 'offline', 'for', 'repairs', ',', 'and', 'the', 'spilled', 'chemical', 'C', 'was', 'safely', 'disposed', 'of', '.', 'No', 'injuries', 'were', 'reported', '.']),
#        list(['At', '1:30', 'PM', ',', 'an', 'equipment', 'failure', 'occurred', 'in', 'the', 'separation', 'unit', '.', 'The', 'failure', 'was', 'caused', 'by', 'a', 'faulty', 'valve', ',', 'which', 'resulted', 'in', 'a', 'release', 'of', 'chemicals', 'A', 'and', 'B', '.', 'The', 'release', 'was', 'contained', 'using', 'the', 'appropriate', 'spill', 'containment', 'materials', ',', 'and', 'the', 'impacted', 'area', 'was', 'inspected', 'for', 'any', 'additional', 'hazards', '.', 'The', 'environmental', 'impact', 'of', 'the', 'incident', 'is', 'currently', 'being', 'assessed', '.', 'No', 'injuries', 'were', 'reported', '.']),
#        list(['On', 'December', '27th', 'at', '7:30', 'PM', ',', 'there', 'was', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'incident', 'occurred', 'during', 'the', 'reaction', 'process', 'in', 'the', 'reaction', 'unit', '.', 'A', 'small', 'amount', 'of', 'chemical', 'A', 'was', 'released', 'into', 'the', 'atmosphere', 'due', 'to', 'a', 'failure', 'in', 'the', 'reactor', '.', 'The', 'situation', 'was', 'quickly', 'contained', 'by', 'the', "plant's", 'emergency', 'response', 'team', ',', 'and', 'the', 'reactor', 'was', 'shut', 'down', 'for', 'repairs', '.', 'No', 'injuries', 'were', 'reported', '.']),
#        list(['On', 'February', '28th', 'at', '7:45', 'PM', ',', 'there', 'was', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'incident', 'occurred', 'during', 'the', 'reaction', 'process', 'in', 'the', 'reaction', 'unit', '.', 'A', 'small', 'amount', 'of', 'chemical', 'A', 'was', 'released', 'into', 'the', 'atmosphere', 'due', 'to', 'a', 'failure', 'in', 'the', 'reactor', '.', 'The', 'situation', 'was', 'quickly', 'contained', 'by', 'the', "plant's", 'emergency', 'response', 'team', ',', 'and', 'the', 'reactor', 'was', 'shut', 'down', 'for', 'repairs', '.', 'No', 'injuries', 'were', 'reported', '.']),
#        list(['There', 'has', 'been', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'level', 'of', 'chemical', 'B', 'in', 'the', 'storage', 'tank', 'exceeded', 'the', 'maximum', 'allowed', 'level', ',', 'causing', 'a', 'temporary', 'loss', 'of', 'control', 'in', 'the', 'process', '.', 'The', 'situation', 'was', 'quickly', 'resolved', ',', 'and', 'the', 'process', 'was', 'brought', 'back', 'under', 'control', '.', 'No', 'chemicals', 'were', 'released', ',', 'and', 'no', 'injuries', 'were', 'reported', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['There', 'has', 'been', 'a', 'minor', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'One', 'of', 'the', 'pumps', 'in', 'the', 'storage', 'area', 'for', 'chemical', 'B', 'failed', ',', 'causing', 'a', 'temporary', 'loss', 'of', 'control', 'in', 'the', 'process', '.', 'The', 'situation', 'was', 'quickly', 'resolved', ',', 'and', 'the', 'process', 'was', 'brought', 'back', 'under', 'control', '.', 'No', 'chemicals', 'were', 'released', ',', 'and', 'no', 'injuries', 'were', 'reported', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['At', '1:30', 'PM', ',', 'a', 'worker', 'accidentally', 'mixed', 'chemicals', 'A', 'and', 'B', 'in', 'the', 'separation', 'unit', ',', 'causing', 'a', 'significant', 'explosion', '.', 'Multiple', 'injuries', 'and', 'extensive', 'damage', 'to', 'the', 'separation', 'unit', 'were', 'reported', '.', 'The', 'incident', 'is', 'currently', 'under', 'investigation', '.']),
#        list(['On', 'September', '28th', 'at', '8:', '30', 'AM', ',', 'there', 'was', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'incident', 'occurred', 'during', 'the', 'transfer', 'of', 'chemical', 'B', 'from', 'the', 'storage', 'area', 'to', 'the', 'reaction', 'unit', '.', 'A', 'small', 'leak', 'was', 'detected', 'on', 'the', 'transfer', 'line', ',', 'and', 'the', 'situation', 'was', 'quickly', 'contained', 'by', 'the', "plant's", 'emergency', 'response', 'team', '.', 'The', 'affected', 'line', 'was', 'taken', 'offline', 'for', 'repairs', ',', 'and', 'the', 'leaked', 'chemical', 'B', 'was', 'safely', 'disposed', 'of', '.', 'No', 'injuries', 'were', 'reported', '.']),
#        list(['At', '9:30', 'AM', ',', 'a', 'worker', 'reported', 'a', 'small', 'spill', 'in', 'the', 'reaction', 'unit', '.', 'The', 'spill', 'was', 'caused', 'by', 'a', 'valve', 'that', 'was', 'not', 'properly', 'closed', 'after', 'maintenance', 'work', '.', 'The', 'spill', 'was', 'contained', 'using', 'the', 'appropriate', 'spill', 'containment', 'materials', ',', 'and', 'the', 'impacted', 'area', 'was', 'inspected', 'for', 'any', 'additional', 'hazards', '.', 'No', 'injuries', 'or', 'environmental', 'impacts', 'were', 'reported', '.']),
#        list(['On', 'September', '22nd', 'at', '3:45', 'AM', ',', 'there', 'was', 'a', 'major', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'incident', 'occurred', 'during', 'the', 'reaction', 'process', 'in', 'the', 'reaction', 'unit', '.', 'A', 'catastrophic', 'explosion', 'occurred', 'due', 'to', 'a', 'failure', 'in', 'the', 'pressure', 'relief', 'system', ',', 'causing', 'a', 'large', 'amount', 'of', 'chemicals', 'A', 'and', 'B', 'to', 'be', 'released', 'into', 'the', 'atmosphere', '.', 'The', 'situation', 'was', 'contained', 'by', 'the', "plant's", 'emergency', 'response', 'team', ',', 'but', 'significant', 'damage', 'was', 'done', 'to', 'the', 'plant', 'and', 'the', 'surrounding', 'environment', '.', 'All', 'employees', 'were', 'safely', 'evacuated', ',', 'but', 'there', 'were', 'multiple', 'injuries', 'reported', '.', 'The', 'plant', 'is', 'currently', 'shut', 'down', 'for', 'repairs', '.']),
#        list(['On', 'January', '14th', 'at', '9:45', 'AM', ',', 'there', 'was', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'incident', 'occurred', 'during', 'the', 'reaction', 'process', 'in', 'the', 'reaction', 'unit', '.', 'A', 'small', 'amount', 'of', 'chemical', 'B', 'was', 'released', 'into', 'the', 'atmosphere', 'due', 'to', 'a', 'failure', 'in', 'the', 'reactor', '.', 'The', 'situation', 'was', 'quickly', 'contained', 'by', 'the', "plant's", 'emergency', 'response', 'team', ',', 'and', 'the', 'reactor', 'was', 'shut', 'down', 'for', 'repairs', '.', 'No', 'injuries', 'were', 'reported', '.']),
#        list(['There', 'has', 'been', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'A', 'small', 'fire', 'broke', 'out', 'in', 'the', 'storage', 'area', 'due', 'to', 'an', 'electrical', 'malfunction', '.', 'The', 'fire', 'was', 'quickly', 'extinguished', ',', 'and', 'no', 'injuries', 'were', 'reported', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['At', '8:', '00', 'AM', ',', 'a', 'worker', 'reported', 'an', 'unusual', 'odor', 'coming', 'from', 'the', 'separation', 'unit', '.', 'Upon', 'investigation', ',', 'it', 'was', 'discovered', 'that', 'there', 'was', 'a', 'small', 'leak', 'in', 'the', 'separation', 'unit', '.', 'The', 'affected', 'area', 'was', 'quickly', 'cordoned', 'off', 'to', 'prevent', 'any', 'further', 'leaks', '.', 'The', 'leak', 'was', 'contained', 'using', 'the', 'appropriate', 'spill', 'containment', 'materials', ',', 'and', 'the', 'damaged', 'area', 'was', 'repaired', '.', 'No', 'injuries', 'or', 'environmental', 'impacts', 'were', 'reported', '.']),
#        list(['At', '10:15', 'AM', ',', 'a', 'small', 'fire', 'occurred', 'in', 'the', 'storage', 'area', 'for', 'chemicals', 'A', 'and', 'B', '.', 'The', 'fire', 'was', 'caused', 'by', 'a', 'spark', 'from', 'a', 'piece', 'of', 'equipment', ',', 'which', 'ignited', 'a', 'small', 'amount', 'of', 'spilled', 'chemical', 'A', '.', 'The', 'fire', 'was', 'quickly', 'extinguished', 'using', 'the', 'appropriate', 'fire', 'suppression', 'materials', ',', 'and', 'the', 'impacted', 'area', 'was', 'inspected', 'for', 'any', 'additional', 'hazards', '.', 'No', 'injuries', 'were', 'reported', '.']),
#        list(['There', 'has', 'been', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'One', 'of', 'the', 'pumps', 'in', 'the', 'reaction', 'unit', 'failed', ',', 'causing', 'a', 'temporary', 'loss', 'of', 'control', 'in', 'the', 'process', '.', 'The', 'situation', 'was', 'quickly', 'resolved', ',', 'and', 'the', 'process', 'was', 'brought', 'back', 'under', 'control', '.', 'No', 'chemicals', 'were', 'released', ',', 'and', 'no', 'injuries', 'were', 'reported', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['On', 'February', '22nd', 'at', '4:15', 'PM', ',', 'there', 'was', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'incident', 'occurred', 'during', 'the', 'separation', 'process', 'in', 'the', 'separation', 'unit', '.', 'A', 'failure', 'in', 'the', 'separator', 'caused', 'a', 'small', 'amount', 'of', 'chemicals', 'A', 'and', 'B', 'to', 'be', 'released', 'into', 'the', 'environment', '.', 'The', 'situation', 'was', 'quickly', 'contained', 'by', 'the', "plant's", 'emergency', 'response', 'team', ',', 'and', 'the', 'malfunctioning', 'equipment', 'was', 'shut', 'down', 'for', 'repairs', '.', 'No', 'injuries', 'were', 'reported', '.']),
#        list(['There', 'has', 'been', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'A', 'malfunction', 'in', 'the', 'recirculation', 'system', 'caused', 'a', 'small', 'release', 'of', 'chemicals', 'A', 'and', 'B', 'into', 'the', 'environment', '.', 'The', 'release', 'was', 'contained', 'within', 'the', "plant's", 'boundaries', ',', 'and', 'no', 'injuries', 'were', 'reported', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['On', 'July', '2nd', 'at', '10:30', 'AM', ',', 'there', 'was', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'incident', 'occurred', 'during', 'the', 'transfer', 'of', 'chemical', 'B', 'from', 'the', 'storage', 'area', 'to', 'the', 'reaction', 'unit', '.', 'A', 'small', 'leak', 'was', 'detected', 'on', 'the', 'transfer', 'line', ',', 'and', 'the', 'situation', 'was', 'quickly', 'contained', 'by', 'the', "plant's", 'emergency', 'response', 'team', '.', 'The', 'affected', 'line', 'was', 'taken', 'offline', 'for', 'repairs', ',', 'and', 'the', 'leaked', 'chemical', 'B', 'was', 'safely', 'disposed', 'of', '.', 'No', 'injuries', 'were', 'reported', '.']),
#        list(['There', 'has', 'been', 'a', 'minor', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'One', 'of', 'the', 'storage', 'tanks', 'for', 'chemical', 'A', 'was', 'found', 'to', 'be', 'leaking', '.', 'The', 'leak', 'was', 'quickly', 'contained', 'within', 'the', 'designated', 'area', ',', 'and', 'the', 'chemical', 'was', 'recovered', '.', 'No', 'injuries', 'were', 'reported', ',', 'and', 'the', 'incident', 'did', 'not', 'affect', 'production', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['At', '9:45', 'AM', ',', 'a', 'worker', 'reported', 'a', 'crack', 'in', 'one', 'of', 'the', 'pipelines', 'leading', 'to', 'the', 'reaction', 'unit', '.', 'The', 'crack', 'was', 'caused', 'by', 'corrosion', ',', 'and', 'the', 'affected', 'area', 'was', 'quickly', 'cordoned', 'off', 'to', 'prevent', 'any', 'further', 'leaks', '.', 'The', 'impacted', 'area', 'was', 'inspected', 'for', 'any', 'additional', 'hazards', ',', 'and', 'the', 'damaged', 'pipeline', 'was', 'replaced', '.', 'No', 'injuries', 'or', 'environmental', 'impacts', 'were', 'reported', '.']),
#        list(['On', 'August', '2nd', 'at', '3:00', 'PM', ',', 'there', 'was', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'incident', 'occurred', 'during', 'the', 'transfer', 'of', 'chemical', 'A', 'from', 'the', 'storage', 'area', 'to', 'the', 'reaction', 'unit', '.', 'A', 'small', 'leak', 'was', 'detected', 'on', 'the', 'transfer', 'line', ',', 'and', 'the', 'situation', 'was', 'quickly', 'contained', 'by', 'the', "plant's", 'emergency', 'response', 'team', '.', 'The', 'affected', 'line', 'was', 'taken', 'offline', 'for', 'repairs', ',', 'and', 'the', 'leaked', 'chemical', 'A', 'was', 'safely', 'disposed', 'of', '.', 'No', 'injuries', 'were', 'reported', '.']),
#        list(['At', '3:30', 'PM', ',', 'a', 'worker', 'reported', 'a', 'small', 'leak', 'in', 'the', 'pipeline', 'carrying', 'chemical', 'C', '.', 'The', 'leak', 'was', 'caused', 'by', 'a', 'loose', 'fitting', 'in', 'the', 'pipeline', '.', 'The', 'leak', 'was', 'contained', 'using', 'the', 'appropriate', 'spill', 'containment', 'materials', ',', 'and', 'the', 'impacted', 'area', 'was', 'inspected', 'for', 'any', 'additional', 'hazards', '.', 'No', 'injuries', 'or', 'environmental', 'impacts', 'were', 'reported', '.']),
#        list(['At', '9:30', 'AM', ',', 'a', 'worker', 'reported', 'a', 'malfunctioning', 'pressure', 'valve', 'in', 'the', 'separation', 'unit', '.', 'The', 'malfunction', 'was', 'causing', 'excessive', 'pressure', 'to', 'build', 'up', 'in', 'the', 'unit', ',', 'which', 'could', 'potentially', 'lead', 'to', 'an', 'explosion', '.', 'The', 'issue', 'was', 'resolved', 'by', 'shutting', 'down', 'the', 'separation', 'unit', 'and', 'replacing', 'the', 'faulty', 'valve', '.', 'No', 'injuries', 'or', 'environmental', 'impacts', 'were', 'reported', '.']),
#        list(['There', 'has', 'been', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'A', 'small', 'fire', 'occurred', 'in', 'the', 'storage', 'area', 'for', 'chemical', 'C', 'due', 'to', 'a', 'faulty', 'electrical', 'outlet', '.', 'The', "plant's", 'fire', 'suppression', 'system', 'was', 'activated', ',', 'and', 'the', 'fire', 'was', 'quickly', 'extinguished', '.', 'No', 'injuries', 'were', 'reported', ',', 'and', 'the', 'fire', 'did', 'not', 'affect', 'production', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['There', 'has', 'been', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'One', 'of', 'the', 'pipes', 'in', 'the', 'separation', 'unit', 'ruptured', ',', 'causing', 'a', 'temporary', 'loss', 'of', 'control', 'in', 'the', 'process', '.', 'The', 'situation', 'was', 'quickly', 'resolved', ',', 'and', 'the', 'process', 'was', 'brought', 'back', 'under', 'control', '.', 'Some', 'chemicals', 'were', 'released', ',', 'but', 'the', 'release', 'was', 'contained', 'within', 'the', "plant's", 'boundaries', '.', 'No', 'injuries', 'were', 'reported', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['At', '6:00', 'AM', ',', 'a', 'worker', 'reported', 'a', 'strange', 'smell', 'coming', 'from', 'the', 'reaction', 'unit', '.', 'Upon', 'investigation', ',', 'it', 'was', 'discovered', 'that', 'a', 'small', 'amount', 'of', 'chemical', 'A', 'had', 'leaked', 'due', 'to', 'a', 'faulty', 'valve', '.', 'The', 'affected', 'area', 'was', 'cordoned', 'off', ',', 'and', 'the', 'valve', 'was', 'repaired', '.', 'No', 'injuries', 'or', 'environmental', 'impacts', 'were', 'reported', '.']),
#        list(['There', 'has', 'been', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'A', 'worker', 'was', 'injured', 'when', 'a', 'valve', 'in', 'the', 'reaction', 'unit', 'malfunctioned', ',', 'causing', 'a', 'small', 'release', 'of', 'chemicals', 'A', 'and', 'B', '.', 'The', 'worker', 'was', 'transported', 'to', 'the', 'hospital', 'for', 'treatment', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['At', '11:00', 'AM', ',', 'a', 'pressure', 'drop', 'was', 'detected', 'in', 'the', 'separation', 'unit', '.', 'The', 'cause', 'of', 'the', 'pressure', 'drop', 'was', 'determined', 'to', 'be', 'a', 'blocked', 'outlet', 'valve', '.', 'The', 'valve', 'was', 'unblocked', ',', 'and', 'the', 'pressure', 'in', 'the', 'unit', 'was', 'stabilized', '.', 'Production', 'resumed', 'without', 'incident', '.']),
#        list(['On', 'November', '3rd', 'at', '10:30', 'AM', ',', 'there', 'was', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'incident', 'occurred', 'during', 'the', 'transfer', 'of', 'chemical', 'A', 'from', 'the', 'storage', 'area', 'to', 'the', 'reaction', 'unit', '.', 'A', 'small', 'leak', 'was', 'detected', 'on', 'the', 'transfer', 'line', ',', 'and', 'the', 'situation', 'was', 'quickly', 'contained', 'by', 'the', "plant's", 'emergency', 'response', 'team', '.', 'The', 'affected', 'line', 'was', 'taken', 'offline', 'for', 'repairs', ',', 'and', 'the', 'leaked', 'chemical', 'A', 'was', 'safely', 'disposed', 'of', '.', 'No', 'injuries', 'were', 'reported', '.']),
#        list(['There', 'has', 'been', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'temperature', 'in', 'the', 'reaction', 'unit', 'exceeded', 'the', 'maximum', 'allowed', 'level', ',', 'causing', 'a', 'temporary', 'loss', 'of', 'control', 'in', 'the', 'process', '.', 'The', 'situation', 'was', 'quickly', 'resolved', ',', 'and', 'the', 'process', 'was', 'brought', 'back', 'under', 'control', '.', 'No', 'chemicals', 'were', 'released', ',', 'and', 'no', 'injuries', 'were', 'reported', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['There', 'has', 'been', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'During', 'routine', 'maintenance', 'of', 'the', 'reaction', 'unit', ',', 'a', 'worker', 'accidentally', 'damaged', 'a', 'valve', ',', 'causing', 'a', 'small', 'release', 'of', 'chemical', 'A', '.', 'The', 'release', 'was', 'contained', 'within', 'the', "plant's", 'boundaries', ',', 'and', 'no', 'injuries', 'were', 'reported', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['There', 'has', 'been', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'level', 'of', 'chemical', 'C', 'in', 'the', 'storage', 'tank', 'exceeded', 'the', 'maximum', 'allowed', 'level', ',', 'causing', 'a', 'temporary', 'loss', 'of', 'control', 'in', 'the', 'process', '.', 'The', 'situation', 'was', 'quickly', 'resolved', ',', 'and', 'the', 'process', 'was', 'brought', 'back', 'under', 'control', '.', 'No', 'chemicals', 'were', 'released', ',', 'and', 'no', 'injuries', 'were', 'reported', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['There', 'has', 'been', 'an', 'unplanned', 'event', 'at', 'the', 'chemical', 'plant', '.', 'A', 'reaction', 'in', 'the', 'reaction', 'unit', 'got', 'out', 'of', 'control', ',', 'leading', 'to', 'an', 'explosion', 'that', 'caused', 'significant', 'damage', 'to', 'the', "plant's", 'infrastructure', 'and', 'equipment', '.', 'The', 'explosion', 'also', 'caused', 'a', 'release', 'of', 'chemicals', 'that', 'led', 'to', 'a', 'large', 'fire', '.', 'Several', 'employees', 'were', 'injured', ',', 'and', 'the', 'plant', 'was', 'evacuated', '.', 'The', 'injured', 'employees', 'were', 'transported', 'to', 'the', 'hospital', ',', 'and', 'the', 'fire', 'was', 'eventually', 'extinguished', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['At', '11:15', 'AM', ',', 'a', 'worker', 'reported', 'an', 'issue', 'with', 'the', 'recirculation', 'pump', 'in', 'the', 'reaction', 'unit', '.', 'The', 'issue', 'was', 'causing', 'the', 'chemicals', 'to', 'not', 'be', 'properly', 'mixed', ',', 'potentially', 'leading', 'to', 'an', 'unsafe', 'reaction', '.', 'The', 'issue', 'was', 'resolved', 'by', 'shutting', 'down', 'the', 'reaction', 'unit', 'and', 'repairing', 'the', 'recirculation', 'pump', '.', 'No', 'injuries', 'or', 'environmental', 'impacts', 'were', 'reported', '.']),
#        list(['On', 'December', '24th', 'at', '3:15', 'AM', ',', 'there', 'was', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'incident', 'occurred', 'during', 'the', 'separation', 'process', 'in', 'the', 'separation', 'unit', '.', 'A', 'small', 'amount', 'of', 'chemical', 'B', 'was', 'released', 'into', 'the', 'environment', 'due', 'to', 'a', 'malfunction', 'in', 'the', 'separator', '.', 'The', 'situation', 'was', 'quickly', 'contained', 'by', 'the', "plant's", 'emergency', 'response', 'team', ',', 'and', 'the', 'malfunctioning', 'equipment', 'was', 'shut', 'down', 'for', 'repairs', '.', 'No', 'injuries', 'were', 'reported', '.']),
#        list(['There', 'has', 'been', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'One', 'of', 'the', 'valves', 'in', 'the', 'reaction', 'unit', 'failed', ',', 'causing', 'a', 'release', 'of', 'chemicals', 'A', 'and', 'B', '.', 'The', 'release', 'was', 'quickly', 'contained', 'within', 'the', 'designated', 'area', ',', 'and', 'the', 'chemicals', 'were', 'recovered', '.', 'No', 'injuries', 'were', 'reported', ',', 'and', 'the', 'incident', 'did', 'not', 'affect', 'production', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['There', 'has', 'been', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'A', 'worker', 'noticed', 'a', 'strange', 'smell', 'in', 'the', 'reaction', 'unit', 'and', 'reported', 'it', 'to', 'the', 'supervisor', '.', 'It', 'was', 'determined', 'that', 'a', 'small', 'amount', 'of', 'chemical', 'A', 'had', 'leaked', 'from', 'a', 'valve', '.', 'The', 'area', 'was', 'immediately', 'evacuated', ',', 'and', 'the', 'leak', 'was', 'contained', 'and', 'repaired', '.', 'No', 'injuries', 'were', 'reported', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['At', '11:30', 'AM', ',', 'a', 'worker', 'reported', 'a', 'minor', 'spill', 'of', 'chemical', 'B', 'in', 'the', 'storage', 'area', '.', 'The', 'spill', 'was', 'caused', 'by', 'a', 'worker', 'accidentally', 'knocking', 'over', 'a', 'container', 'of', 'chemical', 'B', '.', 'The', 'affected', 'area', 'was', 'quickly', 'cordoned', 'off', 'to', 'prevent', 'any', 'further', 'leaks', '.', 'The', 'spill', 'was', 'contained', 'using', 'the', 'appropriate', 'spill', 'containment', 'materials', ',', 'and', 'the', 'area', 'was', 'cleaned', 'up', '.', 'No', 'injuries', 'or', 'environmental', 'impacts', 'were', 'reported', '.']),
#        list(['There', 'has', 'been', 'a', 'minor', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'A', 'worker', 'accidentally', 'spilled', 'a', 'small', 'amount', 'of', 'chemical', 'C', 'while', 'transferring', 'it', 'from', 'the', 'storage', 'tank', 'to', 'a', 'transportation', 'container', '.', 'The', 'spill', 'was', 'quickly', 'contained', 'and', 'cleaned', 'up', '.', 'No', 'injuries', 'were', 'reported', ',', 'and', 'the', 'incident', 'did', 'not', 'affect', 'production', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['There', 'has', 'been', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'level', 'of', 'chemical', 'B', 'in', 'the', 'reaction', 'unit', 'was', 'not', 'properly', 'monitored', ',', 'resulting', 'in', 'an', 'overpressure', 'situation', '.', 'This', 'caused', 'a', 'rupture', 'in', 'the', 'piping', ',', 'leading', 'to', 'a', 'leak', 'of', 'chemicals', 'A', 'and', 'B', '.', 'The', 'leak', 'was', 'contained', 'within', 'the', 'designated', 'area', ',', 'and', 'the', 'chemicals', 'were', 'recovered', '.', 'No', 'injuries', 'were', 'reported', ',', 'and', 'the', 'leak', 'did', 'not', 'affect', 'production', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
# ...
#        list(['On', 'October', '25th', 'at', '5:00', 'PM', ',', 'there', 'was', 'a', 'minor', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'incident', 'occurred', 'during', 'the', 'transfer', 'of', 'chemical', 'B', 'from', 'the', 'reaction', 'unit', 'to', 'the', 'storage', 'area', '.', 'A', 'small', 'spill', 'was', 'detected', 'on', 'the', 'transfer', 'line', ',', 'and', 'the', 'situation', 'was', 'quickly', 'contained', 'by', 'the', "plant's", 'emergency', 'response', 'team', '.', 'The', 'affected', 'line', 'was', 'taken', 'offline', 'for', 'repairs', ',', 'and', 'the', 'spilled', 'chemical', 'B', 'was', 'safely', 'disposed', 'of', '.', 'No', 'injuries', 'were', 'reported', '.']),
#        list(['On', 'November', '24th', 'at', '8:', '00', 'PM', ',', 'there', 'was', 'a', 'minor', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'incident', 'occurred', 'during', 'the', 'transfer', 'of', 'chemical', 'C', 'from', 'the', 'separation', 'unit', 'to', 'the', 'storage', 'area', '.', 'A', 'small', 'spill', 'was', 'detected', 'on', 'the', 'transfer', 'line', ',', 'and', 'the', 'situation', 'was', 'quickly', 'contained', 'by', 'the', "plant's", 'emergency', 'response', 'team', '.', 'The', 'affected', 'line', 'was', 'taken', 'offline', 'for', 'repairs', ',', 'and', 'the', 'spilled', 'chemical', 'C', 'was', 'safely', 'disposed', 'of', '.', 'No', 'injuries', 'were', 'reported', '.']),
#        list(['At', '4:30', 'AM', ',', 'a', 'worker', 'reported', 'a', 'small', 'leak', 'in', 'the', 'pipeline', 'carrying', 'chemical', 'A', '.', 'The', 'leak', 'was', 'caused', 'by', 'a', 'loose', 'valve', '.', 'The', 'leak', 'was', 'contained', 'using', 'the', 'appropriate', 'spill', 'containment', 'materials', ',', 'and', 'the', 'impacted', 'area', 'was', 'inspected', 'for', 'any', 'additional', 'hazards', '.', 'No', 'injuries', 'were', 'reported', ',', 'but', 'the', 'environmental', 'impact', 'of', 'the', 'incident', 'is', 'currently', 'being', 'assessed', '.']),
#        list(['At', '9:00', 'AM', ',', 'a', 'worker', 'reported', 'a', 'small', 'spill', 'of', 'chemical', 'C', 'in', 'the', 'storage', 'area', '.', 'The', 'spill', 'was', 'caused', 'by', 'a', 'worker', 'accidentally', 'knocking', 'over', 'a', 'container', 'of', 'chemical', 'C', '.', 'The', 'spill', 'was', 'contained', 'using', 'the', 'appropriate', 'spill', 'containment', 'materials', ',', 'and', 'the', 'impacted', 'area', 'was', 'inspected', 'for', 'any', 'additional', 'hazards', '.', 'No', 'injuries', 'or', 'additional', 'environmental', 'impacts', 'were', 'reported', '.']),
#        list(['On', 'February', '13th', 'at', '2:45', 'PM', ',', 'there', 'was', 'a', 'minor', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'incident', 'occurred', 'during', 'the', 'storage', 'of', 'chemical', 'C', '.', 'A', 'small', 'amount', 'of', 'chemical', 'C', 'spilled', 'due', 'to', 'a', 'malfunction', 'in', 'the', 'storage', 'tank', ',', 'but', 'the', 'spill', 'was', 'quickly', 'contained', 'by', 'the', "plant's", 'emergency', 'response', 'team', '.', 'The', 'spill', 'was', 'cleaned', 'up', ',', 'and', 'the', 'affected', 'area', 'was', 'decontaminated', '.', 'No', 'injuries', 'were', 'reported', '.']),
#        list(['There', 'has', 'been', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'pressure', 'in', 'one', 'of', 'the', 'pipes', 'in', 'the', 'separation', 'unit', 'exceeded', 'the', 'maximum', 'allowed', 'pressure', ',', 'causing', 'a', 'temporary', 'loss', 'of', 'control', 'in', 'the', 'process', '.', 'The', 'situation', 'was', 'quickly', 'resolved', ',', 'and', 'the', 'process', 'was', 'brought', 'back', 'under', 'control', '.', 'No', 'chemicals', 'were', 'released', ',', 'and', 'no', 'injuries', 'were', 'reported', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['At', '10:15', 'AM', ',', 'a', 'worker', 'reported', 'a', 'malfunctioning', 'gauge', 'in', 'the', 'reaction', 'unit', '.', 'The', 'affected', 'area', 'was', 'quickly', 'cordoned', 'off', 'to', 'prevent', 'any', 'further', 'issues', '.', 'The', 'issue', 'was', 'resolved', 'by', 'replacing', 'the', 'faulty', 'gauge', '.', 'No', 'injuries', 'or', 'environmental', 'impacts', 'were', 'reported', '.']),
#        list(['There', 'has', 'been', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'A', 'small', 'fire', 'broke', 'out', 'in', 'the', 'storage', 'area', 'for', 'chemical', 'A', '.', 'The', 'fire', 'was', 'quickly', 'contained', 'and', 'extinguished', ',', 'and', 'no', 'injuries', 'were', 'reported', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['At', '10:45', 'AM', ',', 'a', 'worker', 'reported', 'a', 'malfunctioning', 'pressure', 'relief', 'valve', 'in', 'the', 'reaction', 'unit', '.', 'The', 'malfunction', 'was', 'causing', 'the', 'pressure', 'in', 'the', 'unit', 'to', 'rise', 'to', 'unsafe', 'levels', ',', 'potentially', 'leading', 'to', 'an', 'explosion', '.', 'The', 'issue', 'was', 'resolved', 'by', 'shutting', 'down', 'the', 'reaction', 'unit', 'and', 'replacing', 'the', 'faulty', 'pressure', 'relief', 'valve', '.', 'No', 'injuries', 'or', 'environmental', 'impacts', 'were', 'reported', '.']),
#        list(['There', 'has', 'been', 'an', 'unplanned', 'event', 'at', 'the', 'chemical', 'plant', '.', 'A', 'severe', 'thunderstorm', 'occurred', ',', 'causing', 'a', 'power', 'surge', 'that', 'led', 'to', 'a', 'large', 'fire', 'in', 'the', 'reaction', 'unit', '.', 'The', 'fire', 'quickly', 'spread', ',', 'causing', 'significant', 'damage', 'to', 'the', "plant's", 'infrastructure', 'and', 'equipment', '.', 'Several', 'employees', 'were', 'injured', ',', 'and', 'the', 'plant', 'was', 'evacuated', '.', 'The', 'injured', 'employees', 'were', 'transported', 'to', 'the', 'hospital', ',', 'and', 'the', 'fire', 'was', 'eventually', 'extinguished', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['There', 'has', 'been', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'One', 'of', 'the', 'storage', 'tanks', 'for', 'chemical', 'B', 'was', 'found', 'to', 'be', 'leaking', '.', 'The', 'leak', 'was', 'quickly', 'contained', 'within', 'the', 'designated', 'area', ',', 'and', 'the', 'chemical', 'was', 'recovered', '.', 'No', 'injuries', 'were', 'reported', ',', 'and', 'the', 'incident', 'did', 'not', 'affect', 'production', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['There', 'has', 'been', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'One', 'of', 'the', 'valves', 'in', 'the', 'separation', 'unit', 'malfunctioned', ',', 'causing', 'a', 'temporary', 'loss', 'of', 'control', 'in', 'the', 'process', '.', 'The', 'situation', 'was', 'quickly', 'resolved', ',', 'and', 'the', 'process', 'was', 'brought', 'back', 'under', 'control', '.', 'No', 'chemicals', 'were', 'released', ',', 'and', 'no', 'injuries', 'were', 'reported', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['On', 'June', '23rd', 'at', '2:45', 'PM', ',', 'there', 'was', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'incident', 'occurred', 'during', 'the', 'transfer', 'of', 'chemical', 'A', 'from', 'the', 'storage', 'area', 'to', 'the', 'reaction', 'unit', '.', 'A', 'small', 'leak', 'was', 'detected', 'on', 'the', 'transfer', 'line', ',', 'and', 'the', 'situation', 'was', 'quickly', 'contained', 'by', 'the', "plant's", 'emergency', 'response', 'team', '.', 'The', 'affected', 'line', 'was', 'taken', 'offline', 'for', 'repairs', ',', 'and', 'the', 'leaked', 'chemical', 'A', 'was', 'safely', 'disposed', 'of', '.', 'No', 'injuries', 'were', 'reported', '.']),
#        list(['On', 'July', '30th', 'at', '8:', '15', 'AM', ',', 'there', 'was', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'incident', 'occurred', 'during', 'the', 'transfer', 'of', 'chemical', 'B', 'from', 'the', 'storage', 'area', 'to', 'the', 'reaction', 'unit', '.', 'A', 'small', 'leak', 'was', 'detected', 'on', 'the', 'transfer', 'line', ',', 'and', 'the', 'situation', 'was', 'quickly', 'contained', 'by', 'the', "plant's", 'emergency', 'response', 'team', '.', 'The', 'affected', 'line', 'was', 'taken', 'offline', 'for', 'repairs', ',', 'and', 'the', 'leaked', 'chemical', 'B', 'was', 'safely', 'disposed', 'of', '.', 'No', 'injuries', 'were', 'reported', '.']),
#        list(['At', '1:30', 'PM', ',', 'a', 'catastrophic', 'explosion', 'occurred', 'in', 'the', 'reaction', 'unit', '.', 'The', 'explosion', 'was', 'caused', 'by', 'an', 'uncontrolled', 'chemical', 'reaction', 'between', 'chemicals', 'A', 'and', 'B', '.', 'The', 'explosion', 'resulted', 'in', 'significant', 'damage', 'to', 'the', 'reaction', 'unit', 'and', 'adjacent', 'areas', ',', 'including', 'the', 'storage', 'area', 'for', 'chemical', 'A', '.', 'The', "plant's", 'emergency', 'response', 'team', 'was', 'activated', ',', 'and', 'the', 'area', 'was', 'evacuated', '.', 'Multiple', 'injuries', 'were', 'reported', ',', 'and', 'the', 'impacted', 'area', 'was', 'cordoned', 'off', '.', 'The', 'environmental', 'impact', 'of', 'the', 'incident', 'is', 'currently', 'being', 'assessed', '.', 'The', 'cause', 'of', 'the', 'uncontrolled', 'chemical', 'reaction', 'is', 'currently', 'under', 'investigation', '.']),
#        list(['There', 'has', 'been', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'One', 'of', 'the', 'pumps', 'in', 'the', 'reaction', 'unit', 'failed', ',', 'causing', 'a', 'backup', 'of', 'chemicals', 'A', 'and', 'B', '.', 'The', 'backup', 'resulted', 'in', 'a', 'spill', 'onto', 'the', 'floor', '.', 'The', 'spill', 'was', 'immediately', 'reported', ',', 'and', 'the', 'spill', 'response', 'team', 'was', 'activated', '.', 'The', 'spill', 'was', 'contained', 'within', 'the', 'designated', 'area', 'and', 'cleaned', 'up', 'using', 'absorbent', 'material', '.', 'The', 'area', 'was', 'then', 'decontaminated', '.', 'No', 'injuries', 'were', 'reported', ',', 'and', 'the', 'spill', 'did', 'not', 'affect', 'production', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['At', '4:00', 'PM', ',', 'an', 'unplanned', 'event', 'occurred', 'in', 'the', 'separation', 'unit', ',', 'resulting', 'in', 'a', 'major', 'release', 'of', 'chemical', 'C', '.', 'The', 'incident', 'caused', 'multiple', 'injuries', 'and', 'extensive', 'damage', 'to', 'the', 'unit', '.', 'It', 'was', 'determined', 'that', 'the', 'incident', 'was', 'caused', 'by', 'a', 'malfunctioning', 'temperature', 'control', 'system', '.', 'The', 'incident', 'is', 'currently', 'under', 'investigation', '.']),
#        list(['On', 'February', '16th', 'at', '6:00', 'AM', ',', 'there', 'was', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'incident', 'occurred', 'during', 'the', 'reaction', 'process', 'in', 'the', 'reaction', 'unit', '.', 'A', 'small', 'amount', 'of', 'chemical', 'A', 'was', 'released', 'into', 'the', 'atmosphere', 'due', 'to', 'a', 'failure', 'in', 'the', 'reactor', '.', 'The', 'situation', 'was', 'quickly', 'contained', 'by', 'the', "plant's", 'emergency', 'response', 'team', ',', 'and', 'the', 'reactor', 'was', 'shut', 'down', 'for', 'repairs', '.', 'No', 'injuries', 'were', 'reported', '.']),
#        list(['There', 'has', 'been', 'a', 'serious', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'A', 'large', 'release', 'of', 'chemical', 'A', 'occurred', 'in', 'the', 'reaction', 'unit', ',', 'causing', 'a', 'fire', 'and', 'significant', 'damage', 'to', 'the', 'plant', '.', 'The', 'emergency', 'response', 'team', 'quickly', 'responded', 'to', 'the', 'incident', ',', 'and', 'the', 'fire', 'was', 'extinguished', '.', 'Unfortunately', ',', 'two', 'workers', 'were', 'injured', 'in', 'the', 'incident', 'and', 'have', 'been', 'transported', 'to', 'the', 'hospital', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'a', 'thorough', 'investigation', 'will', 'be', 'conducted', 'to', 'determine', 'the', 'cause', 'of', 'the', 'release', '.']),
#        list(['On', 'September', '16th', 'at', '11:45', 'PM', ',', 'there', 'was', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'The', 'incident', 'occurred', 'during', 'the', 'transfer', 'of', 'chemical', 'C', 'from', 'the', 'separation', 'unit', 'to', 'the', 'storage', 'area', '.', 'A', 'small', 'leak', 'was', 'detected', 'on', 'the', 'transfer', 'line', ',', 'and', 'the', 'situation', 'was', 'quickly', 'contained', 'by', 'the', "plant's", 'emergency', 'response', 'team', '.', 'The', 'affected', 'line', 'was', 'taken', 'offline', 'for', 'repairs', ',', 'and', 'the', 'leaked', 'chemical', 'C', 'was', 'safely', 'disposed', 'of', '.', 'No', 'injuries', 'were', 'reported', '.']),
#        list(['There', 'has', 'been', 'an', 'incident', 'at', 'the', 'chemical', 'plant', '.', 'One', 'of', 'the', 'valves', 'in', 'the', 'reaction', 'unit', 'was', 'left', 'open', ',', 'causing', 'a', 'small', 'leak', 'of', 'chemicals', 'A', 'and', 'B', '.', 'The', 'leak', 'was', 'immediately', 'reported', ',', 'and', 'the', 'valve', 'was', 'closed', '.', 'The', 'area', 'was', 'then', 'decontaminated', '.', 'No', 'injuries', 'were', 'reported', ',', 'and', 'the', 'leak', 'did', 'not', 'affect', 'production', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.']),
#        list(['At', '9:20', 'AM', ',', 'a', 'worker', 'reported', 'a', 'small', 'fire', 'in', 'the', 'storage', 'area', '.', 'The', 'fire', 'was', 'caused', 'by', 'a', 'worker', 'smoking', 'in', 'the', 'area', ',', 'which', 'is', 'prohibited', '.', 'The', 'affected', 'area', 'was', 'quickly', 'cordoned', 'off', 'to', 'prevent', 'any', 'further', 'damage', '.', 'The', 'fire', 'was', 'extinguished', 'using', 'appropriate', 'firefighting', 'equipment', ',', 'and', 'the', 'area', 'was', 'cleaned', 'up', '.', 'No', 'injuries', 'or', 'environmental', 'impacts', 'were', 'reported', '.']),
#        list(['There', 'has', 'been', 'an', 'unplanned', 'event', 'at', 'the', 'chemical', 'plant', '.', 'At', 'approximately', '2:30', 'PM', ',', 'there', 'was', 'a', 'sudden', 'and', 'violent', 'reaction', 'between', 'chemicals', 'A', 'and', 'B', 'in', 'the', 'reaction', 'unit', '.', 'The', 'reaction', 'produced', 'excessive', 'heat', 'and', 'pressure', ',', 'causing', 'an', 'explosion', '.', 'The', 'explosion', 'damaged', 'the', 'reaction', 'unit', 'and', 'caused', 'a', 'fire', '.', 'The', "plant's", 'emergency', 'response', 'team', 'immediately', 'activated', 'and', 'contained', 'the', 'fire', '.', 'The', 'injured', 'employees', 'were', 'transported', 'to', 'the', 'hospital', ',', 'and', 'the', 'plant', 'was', 'evacuated', '.', 'The', 'incident', 'report', 'has', 'been', 'filed', ',', 'and', 'corrective', 'action', 'will', 'be', 'taken', 'to', 'prevent', 'future', 'incidents', '.'])],
#       dtype=object)

# %%
# Attach Doc2vec labels to each of our tokens
def labelizeReports(reports, label_type):
    labelized = []
    for i,v in tqdm(enumerate(reports)):
        label = '%s_%s'%(label_type,i)
        labelized.append(TaggedDocument(v, [label]))
    return labelized

X_train = labelizeReports(X_train, 'TRAIN')
X_test = labelizeReports(X_test, 'TEST')
# Out:
# 240it [00:00, 1218683.97it/s]
# 60it [00:00, 75663.93it/s]

# %%
# Fit train model
tweet_w2v = Word2Vec(vector_size=300, min_count=10)
tweet_w2v.build_vocab([x.words for x in tqdm(X_train)])
tweet_w2v.train([x.words for x in tqdm(X_train)], total_examples=tweet_w2v.corpus_count, epochs=tweet_w2v.epochs)
# Out:
# 100%|██████████| 240/240 [00:00<00:00, 764918.66it/s]
# 100%|██████████| 240/240 [00:00<00:00, 2335575.31it/s]
# (39106, 90025)

# %%
 google_vectors = gensim.downloader.load('word2vec-google-news-300')

# %%
# Extract word embeddings
vectorizer = TfidfVectorizer(analyzer=lambda x: x, min_df=10)
matrix = vectorizer.fit_transform([x.words for x in X_train])
tfidf = dict(zip(vectorizer.get_feature_names(), vectorizer.idf_))
# Out:
# /Users/andrewsimon/Library/Python/3.8/lib/python/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
# Build word vectors from embeddings
def buildWordVector(tokens, size):
    vec = np.zeros(size).reshape((1, size))
    count = 0.
    for word in tokens:
        try:
            vec += google_vectors[word].reshape((1, size)) * tfidf[word]
            count += 1.
        except KeyError: # handling the case where the token is not
                         # in the corpus. useful for testing.
            continue
    if count != 0:
        vec /= count
    return vec

# %%
# Data postprocessing with sklearn, creating unit standard deviation
from sklearn.preprocessing import scale
train_vecs_w2v = np.concatenate([buildWordVector(z, 300) for z in tqdm(map(lambda x: x.words, X_train))])
train_vecs_w2v = scale(train_vecs_w2v)

test_vecs_w2v = np.concatenate([buildWordVector(z, 300) for z in tqdm(map(lambda x: x.words, X_test))])
test_vecs_w2v = scale(test_vecs_w2v)
# Out:
# 240it [00:00, 6061.94it/s]
# 60it [00:00, 6213.63it/s]

# %%
clf_decision_tree = DecisionTreeClassifier()
clf_decision_tree.fit(train_vecs_w2v, y_train)
predictions_DT = clf_decision_tree.predict(test_vecs_w2v)
acc_score = accuracy_score(y_test, predictions_DT)
acc_score
# Out:
# 0.38333333333333336

# %%
classifier = LogisticRegression( max_iter = 100000)
classifier.fit(train_vecs_w2v, y_train)
predictions_LR = classifier.predict(test_vecs_w2v)
score = classifier.score(test_vecs_w2v, y_test)
score
# Out:
# 0.7

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=800, random_state=11).fit(train_vecs_w2v, y_train)
predictions = rf.predict(test_vecs_w2v)
score = rf.score(test_vecs_w2v, y_test)
score
# Out:
# 0.7166666666666667

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

len(y_test)
cm = confusion_matrix(y_test, predictions_LR)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels = [1,2,3,4,5])
disp.plot()

# %%
len(y_test)
cm = confusion_matrix(y_test, predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels = [1,2,3,4,5])
disp.plot()

# %%
len(y_test)
cm = confusion_matrix(y_test, predictions_DT)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels = [1,2,3,4,5])
disp.plot()

# %%
from sklearn import svm

clf = svm.SVC()
clf.fit(train_vecs_w2v, y_train)
SVM_predict = clf.predict(test_vecs_w2v)
score = clf.score(test_vecs_w2v, y_test)
score
# Out:
# 0.6666666666666666

# %%
len(y_test)
cm = confusion_matrix(y_test, SVM_predict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels = [1,2,3,4,5])
disp.plot()
